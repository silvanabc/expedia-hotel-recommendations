# %% [markdown]
# <h3>Kaggle Challenge</h3>
# <h1>Expedia Hotel Recommendations</h1>
# <hr style="height:2px;border:none;color:#333;background-color:#333;"/>
# <b>Part I - Data Analysis</b>

# %% [markdown]
# ### Imports

# %%
print("Import")
import numpy as np
import pandas as pd
from datetime import timedelta as td
import time
import datetime
pd.set_option('display.max_columns', 500)

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 7.0)
# Out:
# Import

# %%
t0 = time.time()
print(datetime.datetime.now())
expediaDF = pd.read_csv('data/train.csv', 
#                         nrows=1000000,
#                         compression='gzip',
                        error_bad_lines=False)
print(datetime.datetime.now())
# Out:
# 2019-04-06 12:42:10.274524
# 2019-04-06 12:49:12.470121

# %%
destinationDF = pd.read_csv('data/destinations.csv.gz', compression='gzip',
                   error_bad_lines=False)

# %%
expediaDF.head()
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-08-11 07:46:59          2               3                     66
# 1  2014-08-11 08:22:12          2               3                     66
# 2  2014-08-11 08:24:33          2               3                     66
# 3  2014-08-09 18:05:16          2               3                     66
# 4  2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package  channel     srch_ci     srch_co  \
# 0       12          0           1        9  2014-08-27  2014-08-31
# 1       12          0           1        9  2014-08-29  2014-09-02
# 2       12          0           0        9  2014-08-29  2014-09-02
# 3       93          0           0        3  2014-11-23  2014-11-28
# 4       93          0           0        3  2014-11-23  2014-11-28
#
#    srch_adults_cnt  srch_children_cnt  srch_rm_cnt  srch_destination_id  \
# 0                2                  0            1                 8250
# 1                2                  0            1                 8250
# 2                2                  0            1                 8250
# 3                2                  0            1                14984
# 4                2                  0            1                14984
#
#    srch_destination_type_id  is_booking  cnt  hotel_continent  hotel_country  \
# 0                         1           0    3                2             50
# 1                         1           1    1                2             50
# 2                         1           0    1                2             50
# 3                         1           0    1                2             50
# 4                         1           0    1                2             50
#
#    hotel_market  hotel_cluster
# 0           628              1
# 1           628              1
# 2           628              1
# 3          1457             80
# 4          1457             21

# %%
expediaDF.describe()
# Out:
#             site_name  posa_continent  user_location_country  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         9.731860        2.634367              84.824758
# std         12.167062        0.799402              55.612803
# min          2.000000        0.000000               0.000000
# 25%          2.000000        3.000000              66.000000
# 50%          2.000000        3.000000              66.000000
# 75%         13.000000        3.000000              69.000000
# max         53.000000        4.000000             239.000000
#
#        user_location_region  user_location_city  orig_destination_distance  \
# count        1000000.000000      1000000.000000              629753.000000
# mean             319.487129        27877.486461                2012.650225
# std              217.538183        16690.723534                2268.741849
# min                0.000000            0.000000                   0.005600
# 25%              174.000000        13476.000000                 324.314100
# 50%              317.000000        27731.000000                1158.510400
# 75%              403.000000        42397.000000                2591.272700
# max             1025.000000        56507.000000               11946.220200
#
#             user_id       is_mobile      is_package         channel  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   5.775807e+05        0.134856        0.253458        5.840012
# std    3.292401e+05        0.341570        0.434991        3.730820
# min    1.200000e+01        0.000000        0.000000        0.000000
# 25%    3.024860e+05        0.000000        0.000000        2.000000
# 50%    5.798110e+05        0.000000        0.000000        9.000000
# 75%    8.498740e+05        0.000000        1.000000        9.000000
# max    1.198784e+06        1.000000        1.000000       10.000000
#
#        srch_adults_cnt  srch_children_cnt     srch_rm_cnt  \
# count   1000000.000000     1000000.000000  1000000.000000
# mean          2.023743           0.327135        1.117595
# std           0.910264           0.725370        0.468953
# min           0.000000           0.000000        0.000000
# 25%           2.000000           0.000000        1.000000
# 50%           2.000000           0.000000        1.000000
# 75%           2.000000           0.000000        1.000000
# max           9.000000           9.000000        8.000000
#
#        srch_destination_id  srch_destination_type_id      is_booking  \
# count       1000000.000000            1000000.000000  1000000.000000
# mean          14511.167748                  2.590600        0.082096
# std           11091.836907                  2.154406        0.274511
# min               1.000000                  1.000000        0.000000
# 25%            8267.000000                  1.000000        0.000000
# 50%            9524.000000                  1.000000        0.000000
# 75%           18998.000000                  5.000000        0.000000
# max           65102.000000                  9.000000        1.000000
#
#                   cnt  hotel_continent   hotel_country    hotel_market  \
# count  1000000.000000   1000000.000000  1000000.000000  1000000.000000
# mean         1.478440         3.209053       80.961941      601.094632
# std          1.217883         1.660580       55.470145      515.850638
# min          1.000000         0.000000        0.000000        0.000000
# 25%          1.000000         2.000000       50.000000      155.000000
# 50%          1.000000         2.000000       50.000000      587.000000
# 75%          2.000000         4.000000      105.000000      701.000000
# max        120.000000         6.000000      212.000000     2117.000000
#
#         hotel_cluster
# count  1000000.000000
# mean        49.894015
# std         28.962143
# min          0.000000
# 25%         25.000000
# 50%         49.000000
# 75%         73.000000
# max         99.000000

# %%
destinationDF.head()
# Out:
#    srch_destination_id        d1        d2        d3        d4        d5  \
# 0                    0 -2.198657 -2.198657 -2.198657 -2.198657 -2.198657
# 1                    1 -2.181690 -2.181690 -2.181690 -2.082564 -2.181690
# 2                    2 -2.183490 -2.224164 -2.224164 -2.189562 -2.105819
# 3                    3 -2.177409 -2.177409 -2.177409 -2.177409 -2.177409
# 4                    4 -2.189562 -2.187783 -2.194008 -2.171153 -2.152303
#
#          d6        d7        d8        d9       d10       d11       d12  \
# 0 -1.897627 -2.198657 -2.198657 -1.897627 -2.198657 -2.198657 -2.198657
# 1 -2.165028 -2.181690 -2.181690 -2.031597 -2.181690 -2.181690 -2.181690
# 2 -2.075407 -2.224164 -2.118483 -2.140393 -2.224164 -2.209855 -2.224164
# 3 -2.115485 -2.177409 -2.177409 -2.177409 -2.177409 -2.161081 -2.177409
# 4 -2.056618 -2.194008 -2.194008 -2.145911 -2.194008 -2.089094 -2.194008
#
#         d13       d14       d15       d16       d17       d18       d19  \
# 0 -2.198657 -2.198657 -2.198657 -1.897627 -2.198657 -2.198657 -2.198657
# 1 -2.181690 -2.181690 -2.181690 -2.181690 -2.181690 -2.181690 -2.181
-2.198657 -2.198657 -2.198657 -2.198657 -2.198657 -2.198657
# 1 -2.148982 -2.181690 -2.181690 -2.181690 -2.181690 -2.148982 -2.181690
# 2 -2.117811 -2.224164 -2.180182 -2.224164 -2.224164 -2.214572 -2.186008
# 3 -2.130158 -2.177409 -2.177409 -2.177409 -2.177409 -2.115485 -2.177409
# 4 -2.099302 -2.194008 -2.194008 -2.194008 -2.194008 -2.151470 -2.194008
#
#        d139      d140      d141      d142      d143      d144      d145  \
# 0 -2.198657 -2.198657 -2.198657 -2.198657 -2.198657 -2.198657 -2.198657
# 1 -2.181690 -2.165028 -2.181690 -2.165028 -2.181690 -2.181690 -2.165028
# 2 -2.191569 -2.224164 -2.224164 -2.196379 -2.224164 -2.192009 -2.224164
# 3 -2.161081 -2.161081 -2.177409 -2.177409 -2.177409 -2.177409 -2.177409
# 4 -2.163242 -2.187356 -2.194008 -2.191779 -2.194008 -2.194008 -2.185161
#
#        d146      d147      d148      d149
# 0 -2.198657 -2.198657 -2.198657 -2.198657
# 1 -2.181690 -2.181690 -2.181690 -2.181690
# 2 -2.224164 -2.224164 -2.224164 -2.057548
# 3 -2.177409 -2.177409 -2.177409 -2.177409
# 4 -2.194008 -2.194008 -2.194008 -2.188037

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# - How many data?

# %%
print('Rows: ',expediaDF['site_name'].size)
# Out:
# Rows:  37670293

# %% [markdown]
# - How many features?

# %%
print('No. of Features: ',expediaDF.shape[1])
# Out:
# No. of Features:  24

# %% [markdown]
# - How many hotel market?

# %%
uniq = expediaDF.hotel_market.unique().size
print('No. of hotel market: ', uniq)
# Out:
# No. of hotel market:  2118

# %% [markdown]
# - How many distinct values of each feature?

# %%
uniq = expediaDF.nunique().reset_index()
uniq.columns = ["feature", "count"]
uniq
# Out:
#                       feature     count
# 0                   date_time  25419546
# 1                   site_name        45
# 2              posa_continent         5
# 3       user_location_country       237
# 4        user_location_region      1008
# 5          user_location_city     50447
# 6   orig_destination_distance   8495289
# 7                     user_id   1198786
# 8                   is_mobile         2
# 9                  is_package         2
# 10                    channel        11
# 11                    srch_ci      1269
# 12                    srch_co      1262
# 13            srch_adults_cnt        10
# 14          srch_children_cnt        10
# 15                srch_rm_cnt         9
# 16        srch_destination_id     59455
# 17   srch_destination_type_id        10
# 18                 is_booking         2
# 19                        cnt       104
# 20            hotel_continent         7
# 21              hotel_country       213
# 22               hotel_market      2118
# 23              hotel_cluster       100

# %% [markdown]
# ### Types of the features

# %%
fig, ax = plt.subplots()

types = expediaDF.dtypes.value_counts()

sns.barplot(types.index, types.values)
ax.set_ylabel("Quantity")
ax.set_xlabel("Type")
ax.set_title('Features Quantity per Type')
# Out:
# Text(0.5,1,'Features Quantity per Type')

# %% [markdown]
# ### Hotel Clusters

# %%
uniqueClusters = expediaDF['hotel_cluster'].unique().size
print("Total n. hotel clusters: ", uniqueClusters)
# Out:
# Total n. hotel clusters:  100

# %%
print("Distribution of the Hotel Clusters")
sns.distplot(expediaDF['hotel_cluster']);
# Out:
# Distribution of the Hotel Clusters

# %%
print("Distribution of the Hotel Clusters Value Counts")
sns.distplot(expediaDF['hotel_cluster'].value_counts());

# %% [markdown]
# ### Users

# %%
uniqueUsers = expediaDF['user_id'].unique().size
print("Total n. usuários: ", uniqueUsers)
# Out:
# Total n. usuários:  1198786

# %%
plt.figure(figsize=(10,7))
sns.boxplot(expediaDF['user_id'].value_counts(),showfliers=False)
plt.title('Box Plot of the Users')
plt.xlabel('Quantity')
plt.show()

# %%
print("Distribution of User Value Counts")
sns.distplot(expediaDF['user_id'].value_counts());
plt.title("Distribution of User Count")
plt.show()
# Out:
# Distribution of User Value Counts

# %% [markdown]
# ### Destination

# %%
unique = expediaDF['srch_destination_id'].unique().size
print("Total n. destinations: ", unique)
# Out:
# Total n. destinations:  59455

# %%
plt.figure(figsize=(10,7))
sns.boxplot(expediaDF['srch_destination_id'].value_counts(),showfliers=False)
plt.title('Box Plot of the Destinations')
plt.xlabel('Count')
plt.show()

# %%
print("Distribution of Destination Count")
sns.distplot(expediaDF['srch_destination_id'].value_counts());
plt.title("Distribution of Destination Count")
plt.show()
# Out:
# Distribution of Destination Count

# %%
expediaDF.shape
# Out:
# (37670293, 24)

# %% [markdown]
# ### Type of Destination

# %%
unique = expediaDF['srch_destination_type_id'].unique().size
print("Total n. type of destinations: ", unique)
# Out:
# Total n. type of destinations:  10

# %%
destTypeCount  = expediaDF['srch_destination_type_id'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(destTypeCount.index, destTypeCount.values)
plt.title('Destination Type')
plt.ylabel('Number of Occurrences')
plt.xlabel('Type of destination')
plt.show()

# %% [markdown]
# ### Booking vs Click

# %%
#1 is booking, 0 click
bookingCount = expediaDF.is_booking.value_counts()
bookingCount.index = ["Click",  "Booking"]
sns.barplot(bookingCount.index, bookingCount.values)

ax.set_ylabel("Quantity")
ax.set_xlabel("Type")
ax.set_title('Features Quantity per Type')
print(bookingCount)
# Out:
# Click      34669600
# Booking     3000693
# Name: is_booking, dtype: int64

# %%
bookingCount.plot(kind='pie', figsize=(7,7), title="", autopct='%1.0f%%')

# %% [markdown]
# ### Missing Values

# %%
missingValues = expediaDF.isnull().sum().sort_values(ascending=False)
print('**Missing values** ')
print(missingValues[missingValues > 0])
sns.barplot(missingValues.values, missingValues.index)
# Out:
# **Missing values**
# orig_destination_distance    13525001
# srch_co                         47084
# srch_ci                         47083
# dtype: int64

# %% [markdown]
# ### Checkin / Checkout

# %%
checkInOut = expediaDF.dropna(subset = ['srch_ci', 'srch_co'])

# %%
size = checkInOut[checkInOut['srch_co'] < checkInOut['srch_ci']].size
print("Checkin after  Checkout: ", size)
# Out:
# Checkin after  Checkout:  19152

# %%
checkInOut = checkInOut[checkInOut['srch_co'] > checkInOut['srch_ci']] #normalization
checkInOut['srch_ci'] = checkInOut['srch_ci'].astype('datetime64[ns]')
checkInOut['srch_co'] = checkInOut['srch_co'].astype('datetime64[ns]')
diff = checkInOut['srch_co'] - checkInOut['srch_ci']
checkInOut['duration'] = (diff / np.timedelta64(1, 'D')).astype(int)

# %%
diffCount = diff.value_counts()
diffCount.index = (diffCount.index / np.timedelta64(1, 'D')).astype(int)
diffCount = diffCount.sort_values(ascending=False)
top10 = diffCount[:10]

sns.barplot(top10.index, top10.values)
plt.title('Duration of Stay')
plt.ylabel('Number of Occurrences')
plt.xlabel('Duration')
plt.show()

# %%
data = checkInOut.groupby('hotel_cluster').duration.mean()

plt.figure(figsize=(20,10))
sns.barplot(data.index, data.values)
plt.title('Duration of Stay per Hotel Cluster', fontsize=18)
plt.ylabel('Duration', fontsize=18)
plt.xlabel('Hotel Cluster', fontsize=18)
plt.show()

# %%
del checkInOut
del diff
del diffCount

# %% [markdown]
# ### Search numbers

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(15,10))

adultsCnt = expediaDF.srch_adults_cnt.value_counts()
sns.barplot(adultsCnt.index, adultsCnt.values, ax=ax1)
# sns.countplot(adultsCnt, ax=ax1)
ax1.set_title('Number of adults per room')

childrenCnt = expediaDF.srch_children_cnt.value_counts()
sns.barplot(childrenCnt.index, childrenCnt.values, ax=ax2)
ax2.set_title('Number of children per room')

roomCnt = expediaDF.srch_rm_cnt.value_counts()
sns.barplot(roomCnt.index, roomCnt.values, ax=ax3)
ax3.set_title('Number of rooms')

destTypeCnt = expediaDF.srch_destination_type_id.value_counts()
sns.barplot(destTypeCnt.index, destTypeCnt.values, ax=ax4)
ax4.set_title('Destination Type')

plt.show()

# %% [markdown]
# ### Boolean values

# %%
fig, (ax1,ax2) = plt.subplots(1,2)

# sns.countplot(expediaDF["is_mobile"], ax=ax1)
ax1.set_title('Mobile Device')

# sns.countplot(expediaDF["is_package"], ax=ax2)
ax2.set_title('Part of a package')

# bookingCount.plot(kind='pie', figsize=(7,7), title="", autopct='%1.0f%%')
expediaDF.is_mobile.value_counts().plot(kind='pie', figsize=(14,7), title="", autopct='%1.0f%%', ax=ax1)
expediaDF.is_package.value_counts().plot(kind='pie', figsize=(14,7), title="", autopct='%1.0f%%', ax=ax2)

plt.show()

# %% [markdown]
# ### Correlation Map

# %%
CorrelationMat=expediaDF.corr().abs()
sns.clustermap(CorrelationMat, center=0, cmap="GnBu",
               linewidths=.75, figsize=(10, 10), metric="correlation")
plt.show()
savefig('corrMap.jpg')

# %%
sorted_corr = (CorrelationMat.loc[:, ["hotel_cluster"]].sort_values(by="hotel_cluster", ascending=False).T)
plt.figure(figsize=(24, .5))
ax = sns.heatmap(sorted_corr, annot=True, annot_kws={"size":13, "weight":"bold"}, fmt=".2f", linewidths=1, cbar=False, cmap="Blues")
for label in ax.get_xticklabels()+ax.get_yticklabels():
    label.set_fontsize(15)
plt.title("Correlations coefficients with Hotel Cluster")
ax.title.set_fontsize(24)
plt.show()

# %% [markdown]
# ## Features correlated to Hotel Cluster

# %% [markdown]
# - Destinations per Hotel Cluster

# %%
smallDF = expediaDF[:1000]

# %%
data = expediaDF.groupby('hotel_cluster').srch_destination_id.nunique()

plt.figure(figsize=(20,10))
sns.barplot(data.index, data.values)
plt.title('Destinations by Hotel Cluster', fontsize=18)
plt.ylabel('Quantity of Destinations', fontsize=18)
plt.xlabel('Hotel Cluster', fontsize=18)
plt.show()

# %% [markdown]
# - Mean of number of adults by hotel cluster

# %%
data = expediaDF.groupby('hotel_cluster').srch_adults_cnt.mean()

plt.figure(figsize=(20,5))
sns.barplot(data.index, data.values)
plt.title('Mean of adults per hotel cluster', fontsize=18)
plt.ylabel('Mean of adults', fontsize=18)
plt.xlabel('Hotel Cluster', fontsize=18)
plt.show()

# %% [markdown]
# - Mean of number of children per hotel cluster

# %%
data = expediaDF.dropna(subset=['srch_children_cnt'])
data = data[data.srch_children_cnt > 0]
data = data.groupby('hotel_cluster').srch_children_cnt.mean()

plt.figure(figsize=(20,5))
sns.barplot(data.index, data.values)
plt.title('Mean of children per hotel cluster', fontsize=18)
plt.ylabel('Mean of children', fontsize=18)
plt.xlabel('Hotel Cluster', fontsize=18)
plt.show()

# %% [markdown]
# ### Popular Hotel Cluster

# %% [markdown]
# - Popular Hotel Cluster per Destination

# %%
popularClustersDF = expediaDF.groupby(['srch_destination_id']).hotel_cluster.value_counts().to_frame()
popularClustersDF[:10]
# Out:
#                                    hotel_cluster
# srch_destination_id hotel_cluster
# 0                   3                          2
# 1                   20                        26
#                     30                        22
#                     60                        17
#                     57                         1
# 2                   30                         5
#                     20                         4
#                     5                          1
#                     38                         1
#                     41                         1

# %% [markdown]
# - Popular Hotel Cluster per Hotel Country

# %%
popularClustersDF = expediaDF.groupby(['hotel_country']).hotel_cluster.value_counts().to_frame()
popularClustersDF[:10]
# Out:
#                              hotel_cluster
# hotel_country hotel_cluster
# 0             8                      34551
#               35                      3924
#               20                      2384
#               22                      2344
#               30                      2274
#               40                      1784
#               78                      1361
#               5                       1309
#               36                       885
#               58                       863

# %% [markdown]
# - Popular Hotel Cluster per Hotel Market

# %%
popularClustersDF = expediaDF.groupby(['hotel_market']).hotel_cluster.value_counts().to_frame()
popularClustersDF[:10]
# Out:
#                             hotel_cluster
# hotel_market hotel_cluster
# 0            3                        788
#              89                       249
#              53                        30
#              57                        18
#              60                        18
# 1            82                       303
#              5                        235
#              78                       156
#              58                        96
#              93                        75

# %% [markdown]
# - Popular Hotel Cluster

# %%
popularClustersDF = expediaDF.hotel_cluster.value_counts().to_frame()
popularClustersDF[:10]
# Out:
#     hotel_cluster
# 91        1043720
# 41         772743
# 48         754033
# 64         704734
# 65         670960
# 5          620194
# 98         589178
# 59         570291
# 42         551605
# 21         550092

# %% [markdown]
# - Popular Hotel Cluster per User Location City

# %%
popularClustersDF = expediaDF.groupby(['user_location_city']).hotel_cluster.value_counts().to_frame()
popularClustersDF[:10]
# Out:
#                                   hotel_cluster
# user_location_city hotel_cluster
# 0                  91                        54
#                    50                        42
#                    65                        39
#                    54                        36
#                    18                        27
#                    48                        27
#                    92                        27
#                    63                        24
#                    66                        24
#                    23                        23
